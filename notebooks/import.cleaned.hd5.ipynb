# %%
import pandas as pd
import gzip

# %cd /Users/nolanthomas/Public/amazon/raw

df_meta = pd.read_hdf('cleaned.hd5')
df_meta.head()
# Out:
# /Users/nolanthomas/Public/amazon/raw
#                 BRAND                                    FEATURE_BULLETS  \
# 0              Suunto  [Imported, Watch, altimeter, barometer, and co...
# 1            AmeriBag  [Nylon, Easy-see silver nylon lining, Double-z...
# 2  Palm Beach Jewelry  [Top Rated Seller - Trusted Since 1952 - 90 Da...
# 3              Buxton  [Leatherette, Imported, Flap closure, 25" shou...
# 4              Buxton  [Leather, Importado, flap closure, Brush with ...
#
#                                                 NAME ORIGINAL_PRICE  \
# 0  Suunto Vector Wrist-Top Computer Watch with Al...           None
# 1  AmeriBag Distressed Nylon Bag, Taupe, Extra Small         $50.99
# 2  PalmBeach Jewelry Open Weave Decorative Band i...           None
# 3               Buxton Crossbody Mini Cross Body Bag         $23.68
# 4         Buxton Heiress Convertible Billfold Wallet         $15.74
#
#                                  PRODUCT_DESCRIPTION  \
# ...

# %%
df_meta['ORIGINAL_PRICE'].apply(lambda x: x.replace('$', '').replace(',', '') if x != None else None).astype('float')
df_meta['SALE_PRICE'].apply(lambda x: x.replace('$', '').replace(',', '') if x != None else None).astype('float')
df_meta['ASIN'] = df_meta['asin']
df_meta.drop('asin', inplace=True)
# Out:
# -----------------------------------------------
# ValueError    Traceback (most recent call last)
# <ipython-input-10-34eccf5f0c25> in <module>()
# ----> 1 df_meta['ORIGINAL_PRICE'].apply(lambda x: x.replace('$', '').replace(',', '') if x != None else None).astype('float')
#       2 df_meta['SALE_PRICE'].apply(lambda x: x.replace('$', '').replace(',', '') if x != None else None).astype('float')
#       3 df_meta['ASIN'] = df_meta['asin']
#       4 df_meta.drop('asin', inplace=True)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
# ...
